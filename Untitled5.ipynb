# %% [markdown]
# <a href="https://colab.research.google.com/github/sanchitsetia/Machine-Learning-practise-notebooks/blob/master/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! wget --header="Host: doc-0o-0k-docs.googleusercontent.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-GB,en-US;q=0.9,en;q=0.8" --header="Referer: https://drive.google.com/" --header="Cookie: AUTH_idq2k25ur6og81s0nlqq5fdscfg1l3er=17015832539684249098|1604322375000|bg1pagb4gvdhst1ibeso7v7thudnlc5i; AUTH_idq2k25ur6og81s0nlqq5fdscfg1l3er_nonce=8strjbq1je4l8" --header="Connection: keep-alive" "https://doc-0o-0k-docs.googleusercontent.com/docs/securesc/a8oof3olke6baqv7qeqgv35bgo4rcm0f/j4uj878ovcumthcrlc7tv6kohjrcj6ur/1604322675000/06629147635963609455/17015832539684249098/1QiEgrF7OMNgAkoO4f7pm6vWpVb7Em2cW?e=download&authuser=0&nonce=8strjbq1je4l8&user=17015832539684249098&hash=mfc0q42kl291bvn7j95h8per0p2ppkia" -c -O 'Autopilot-TensorFlow-master.rar'
# Out:
# --2020-11-02 13:12:03--  https://doc-0o-0k-docs.googleusercontent.com/docs/securesc/a8oof3olke6baqv7qeqgv35bgo4rcm0f/j4uj878ovcumthcrlc7tv6kohjrcj6ur/1604322675000/06629147635963609455/17015832539684249098/1QiEgrF7OMNgAkoO4f7pm6vWpVb7Em2cW?e=download&authuser=0&nonce=8strjbq1je4l8&user=17015832539684249098&hash=mfc0q42kl291bvn7j95h8per0p2ppkia
# Resolving doc-0o-0k-docs.googleusercontent.com (doc-0o-0k-docs.googleusercontent.com)... 64.233.189.132, 2404:6800:4008:c07::84
# Connecting to doc-0o-0k-docs.googleusercontent.com (doc-0o-0k-docs.googleusercontent.com)|64.233.189.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/rar]
# Saving to: ‘Autopilot-TensorFlow-master.rar’
#
# Autopilot-TensorFlo     [     <=>            ]   2.22G  72.4MB/s    in 18s
#
# 2020-11-02 13:12:21 (130 MB/s) - ‘Autopilot-TensorFlow-master.rar’ saved [2380979121]

# %%
from zipfile import ZipFile
with ZipFile('Autopilot-TensorFlow-master.rar', "r") as z:
    z.extractall()
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-13-5ff13149a079> in <module>()
#       1 from zipfile import ZipFile
# ----> 2 with ZipFile('Autopilot-TensorFlow-master.rar', "r") as z:
#       3     z.extractall()
#
# /usr/lib/python3.6/zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1129         try:
#    1130             if mode == 'r':
# -> 1131                 self._RealGetContents()
#    1132             elif mode in ('w', 'x'):
#    1133                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.6/zipfile.py in _RealGetContents(self)
#    1196             raise BadZipFile("File is not a zip file")
#    1197         if not endrec:
# -> 1198             raise BadZipFile("File is not a zip file")
#    1199         if self.debug > 1:
#    1200             print(endrec)
#
# ...

# %%
# !pip install unrar
# !unrar x 'Autopilot-TensorFlow-master.rar'
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...
